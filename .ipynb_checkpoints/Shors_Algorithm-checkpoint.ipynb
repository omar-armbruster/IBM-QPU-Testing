# %%
import numpy as np
from qiskit import *
from qiskit_aer import *
from qiskit.circuit.library import QFT
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %%
qc = QuantumCircuit(8,8)
qft = QFT(num_qubits=5, approximation_degree=0).to_gate()
invqft = QFT(num_qubits=5, approximation_degree=0, inverse=True).to_gate()
qc.append(qft, qargs=range(0,5))
qc.h(0)
qc.h(1)
qc.x(2)
qc.append(invqft, qargs=range(0,5))
qc.measure(range(0,5), range(0,5))
qc.draw('mpl')
